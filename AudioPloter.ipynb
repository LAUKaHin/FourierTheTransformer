# %%
# imports 
import matplotlib.pyplot as plt 
import numpy as np 
import wave, sys

# %%
target = "Pathogen"

# reading the audio file 
raw = wave.open("Audio/"+target+".wav")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 target = "Pathogen"
#       3 # reading the audio file
# ----> 4 raw = wave.open("Audio/"+target+".wav")
#
# File ~\anaconda3\Lib\wave.py:631, in open(f, mode)
#     629         mode = 'rb'
#     630 if mode in ('r', 'rb'):
# --> 631     return Wave_read(f)
#     632 elif mode in ('w', 'wb'):
#     633     return Wave_write(f)
#
# File ~\anaconda3\Lib\wave.py:283, in Wave_read.__init__(self, f)
#     281 # else, assume it is an open file object already
#     282 try:
# --> 283     self.initfp(f)
#     284 except:
#     285     if self._i_opened_the_file:
#
# File ~\anaconda3\Lib\wave.py:248, in Wave_read.initfp(self, file)
#     246 self._convert = None
#     247 self._soundpos = 0
# --> 248 self._file = _Chunk(file, bigendian = 0)
#     249 if self._file.getname() != b'RIFF':
#     250     raise Error('file does not start with RIFF id')
#
# File ~\anaconda3\Lib\wave.py:114, in _Chunk.__init__(self, file, align, bigendian, inclheader)
#     112 self.chunkname = file.read(4)
#     113 if len(self.chunkname) < 4:
# --> 114     raise EOFError
#     115 try:
#     116     self.chunksize = struct.unpack_from(strflag+'L', file.read(4))[0]
#
# EOFError:

# %%
# reads all the frames  
# -1 indicates all or max frames 
signal = raw.readframes(-1) 
signal = np.frombuffer(signal, dtype ="int16")

# %%
# gets the frame rate 
f_rate = raw.getframerate()

# %%
# to Plot the x-axis in seconds  
# you need get the frame rate  
# and divide by size of your signal 
# to create a Time Vector  
# spaced linearly with the size  
# of the audio file 
time = np.linspace( 
    0, # start 
    len(signal) / f_rate, 
    num = len(signal) 
)

# %%
# using matplotlib to plot 
# creates a new figure 
plt.figure(figsize=(max(time)+1, 1))
plt.xticks(np.arange(min(time), max(time)+1, step=1))

# title of the plot 
plt.title("Sound Wave") 

# label of x-axis 
plt.xlabel("Time") 

# actual plotting 
plt.plot(time, signal) 
plt.margins(x=0)
# shows the plot  
# in new window 
plt.show()

# %%
# you can also save 
# the plot using 
plt.savefig(target, dpi=1600)

# %%
print(max(time))
# Out:
# 514.2755555555556

# %%
print(len(signal))
# Out:
# 22679552
